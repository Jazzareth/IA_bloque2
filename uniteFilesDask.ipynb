# %%
import os
import time
import numpy as np
import pandas as pd
import dask
import dask.dataframe as dd
import shutil
path=''

# %%
from dask.distributed import Client
client = Client(n_workers=3, processes=True)
client
# Out:
# <Client: 'tcp://127.0.0.1:51059' processes=3 threads=12, memory=11.92 GiB>

# %%
contenido = os.listdir(path)
contenido
# Out:
# ['example0.csv',
#  'example1.csv',
#  'example10.csv',
#  'example2.csv',
#  'example3.csv',
#  'example4.csv',
#  'example5.csv',
#  'example6.csv',
#  'example7.csv',
#  'example8.csv',
#  'example9.csv']

# %%
#Crear DataFrame con todos los archivos
#DataFrame para unir los csv en uno solo con una columna con el nombre de cada archivo para distingirlos y clasificarlos
filesp = path + '*.csv'
ddf=dd.read_csv(filesp)

# %%
ddf.head(5)
# Out:
#    Unnamed: 0  time  col5_float  col7_float  col9_float  col11_float  \
# 0           0   990    0.404903    0.794341    0.079705     0.987766
# 1           1     1    0.360621    0.660183    0.950432     0.051235
# 2           2     2    0.959162    0.421440    0.617876     0.847244
# 3           3     3    0.328729    0.964067    0.306752     0.484405
# 4           4     4    0.132041    0.320748    0.362068     0.630939
#
#    col13_float  col15_float  col17_float  col19_float  col21_float  \
# 0     0.626749     0.380695     0.147410     0.120181     0.355822
# 1     0.283044     0.841807     0.142965     0.310050     0.791161
# 2     0.522461     0.472585     0.156862     0.933377     0.324985
# 3     0.328099     0.530360     0.804521     0.539465     0.130517
# 4     0.239689     0.687089     0.826416     0.097794     0.140574
#
#    col23_float  col25_float  col27_float  target_boolean  col31_integer  \
# 0     0.456081     0.196255     0.239259               0             15
# 1     0.305067     0.761837     0.022378               0             72
# 2     0.672343     0.658205     0.262042               0             20
# 3     0.798976     0.639729     0.349704               0             85
# 4     0.977748     0.927153     0.805324               0             70
#
#    col33_integer  col35_integer         Fname
# 0             10            115  example0.csv
# 1             39             19  example0.csv
# 2             72             84  example0.csv
# 3            111              7  example0.csv
# 4             77             95  example0.csv

# %%
fname = path + 'mergedCSV.csv'
ddf.to_csv(fname, single_file=True)
# Out:
# ['D:\\Principal\\Escuela\\Actual\\TEC\\semestre7\\bloque2_IA\\reto\\f\\uniteFiles\\cfiles\\mergedCSV.csv']

# %%
client.close()
